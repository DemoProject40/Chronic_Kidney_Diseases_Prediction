# %%
#import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import lux

import warnings
warnings.filterwarnings("ignore") 

# %matplotlib inline

# %%
path = '../data/raw/kidney_disease.csv'
df = pd.read_csv(path)

# %%
df.head(n=10)
# Out:
#    id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0   0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1   1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2   2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3   3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4   4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5   5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6   6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7   7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8   8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9   9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
#
#            ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 0  notpresent  ...   44   7800  5.2  yes  yes   no  good   no   no
# 1  notpresent  ...   38   6000  NaN   no   no   no  good   no   no
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.isnull().sum()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
from sklearn.impute import SimpleImputer
imp_mode = SimpleImputer(missing_values = np.nan,strategy = 'most_frequent')

# %%
data = pd.DataFrame(imp_mode.fit_transform(df))
data.columns = df.columns
data.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
data.isnull().sum()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
for i in data.columns:
    print('================================================================================================================')
    print(i)
    print(set(data[i].tolist()))
# Out:
# ...
# id
# ...

# %%
column = ['cad','dm','wc','pcv','rc','classification']
demo = data[column]

for i in demo.columns:
    print('================================================================================================================')
    print(i)
    print(set(data[i].tolist()))
# Out:
# ...
# cad
# {'no', '\tno', 'yes'}
# ...
# dm
# {'yes', 'no', ' yes', '\tyes', '\tno'}
# ...
# wc
# {'12000', '11400', '8500', '7700', '8400', '\t8400', '11500', '10700', '5800', '14600', '6800', '16300', '11900', '9200', '4200', '4100', '13200', '10500', '6000', '5600', '11300', '7800', '9800', '6500', '13600', '18900', '12100', '11200', '9100', '8300', '9400', '5500', '6200', '7300', '12700', '10900', '12400', '5700', '8100', '10200', '5400', '6900', '14900', '5000', '5900', '\t?', '21600', '4500', '10800', '8600', '10300', '12500', '19100', '5300', '8800', '9600', '7400', '11000', '26400', '15700', '12300', '2600', '8000', '12200', '11800', '9000', '6300', '4700', '9900', '6600', '7000', '4300', '10400', '7900', '5100', '6700', '2200', '9300', '12800', '7500', '8200', '5200', '6400', '7100', '9700', '3800', '7200', '9500', '16700', '\t6200', '15200', '4900'}
# ...
# pcv
# ...

# %%
data['cad'] = data['cad'].apply(lambda x:'no' if x == "\tno" else x )

data['dm'] = data['dm'].apply(lambda x:'no' if x == "\tno" else x )
data['dm'] = data['dm'].apply(lambda x:'yes' if x == "\tyes" else x )
data['dm'] = data['dm'].apply(lambda x:'yes' if x == " yes" else x )

data['rc'] = data['rc'].apply(lambda x:'5.2' if x == "\t?" else x )

data['wc'] = data['wc'].apply(lambda x:'9800' if x == "\t6200" else x )
data['wc'] = data['wc'].apply(lambda x:'9800' if x == "\t8400" else x )
data['wc'] = data['wc'].apply(lambda x:'9800' if x == "\t?" else x )

data['pcv'] = data['pcv'].apply(lambda x:'41' if x == "\t43" else x )
data['pcv'] = data['pcv'].apply(lambda x:'41' if x == "\t?" else x )

data['classification'] = data['classification'].apply(lambda x:'ckd' if x == "ckd\t" else x )

# %%
column = ['cad','dm','wc','pcv','rc','classification']
demo = data[column]

for i in demo.columns:
    print('================================================================================================================')
    print(i)
    print(set(data[i].tolist()))
# Out:
# ...
# cad
# {'no', 'yes'}
# ...
# dm
# {'no', 'yes'}
# ...
# wc
# {'12000', '11400', '8500', '7700', '8400', '11500', '10700', '5800', '14600', '6800', '16300', '11900', '9200', '4200', '4100', '13200', '10500', '6000', '5600', '11300', '7800', '9800', '6500', '13600', '18900', '12100', '11200', '9100', '8300', '9400', '5500', '6200', '7300', '12700', '10900', '12400', '5700', '8100', '10200', '5400', '6900', '14900', '5000', '5900', '21600', '4500', '10800', '8600', '10300', '12500', '19100', '5300', '8800', '9600', '7400', '11000', '26400', '15700', '12300', '2600', '8000', '12200', '11800', '9000', '6300', '4700', '9900', '6600', '7000', '4300', '10400', '7900', '5100', '6700', '2200', '9300', '12800', '7500', '8200', '5200', '6400', '7100', '9700', '3800', '7200', '9500', '16700', '15200', '4900'}
# ...
# pcv
# ...

# %%
data.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
data.describe()
# Out:
#          id    age     bp      sg     al     su     rbc      pc         pcc  \
# count   400  400.0  400.0  400.00  400.0  400.0     400     400         400
# unique  400   76.0   10.0    5.00    6.0    6.0       2       2           2
# top       0   60.0   80.0    1.02    0.0    0.0  normal  normal  notpresent
# freq      1   28.0  128.0  153.00  245.0  339.0     353     324         358
#
#                 ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# count          400  ...  400   400  400  400  400  400   400  400  400
# unique           2  ...   42    89   48    2    2    2     2    2    2
# top     notpresent  ...   41  9800  5.2   no   no   no  good   no   no
# freq           378  ...   93   119  149  253  263  366   318  324  340
#
#        classification
# count             400
# unique              2
# top               ckd
# freq              250
#
# [4 rows x 26 columns]

# %%
from sklearn import preprocessing
_df = data.apply(preprocessing.LabelEncoder().fit_transform)
_df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
_df.to_csv('../data/processed/pre-processed.csv')
